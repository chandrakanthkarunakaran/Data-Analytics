# %% [markdown]
# MATPLOTLIB

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
data=pd.read_csv("CROPSINDIA2002-2022.csv")

# %%
data.fillna(method='ffill',inplace=True)

# %%
dataStates=data.loc[~data["State / Union Territory"].isin(['All India',
 'All States',
 'Union Territories'])]

# %%
dataStates.loc[:,"State"]=[x.split(".")[-1].strip() for x in dataStates["State / Union Territory"]]
# Out:
# c:\users\chand\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
dataStates
# Out:
#     State / Union Territory     Year     Rice  Wheat Coarse cereals  Pulses  \
# 0         1. Andhra Pradesh  2002-03     7327     14           2251  1061.6
# 1         1. Andhra Pradesh  2003-04     8953      7           3498    1239
# 2         1. Andhra Pradesh  2004-05     9601      5           2771    1019
# 3         1. Andhra Pradesh  2005-06    11704      9           3862    1376
# 4         1. Andhra Pradesh  2006-07    11872      9           3001    1347
# ..                      ...      ...      ...    ...            ...     ...
# 562         29. West Bengal  2017-18    14967    312         1154.7   443.8
# 563         29. West Bengal  2018-19  16242.2  337.8         1741.5   368.4
# 564         29. West Bengal  2019-20  15881.4  509.9         2018.1   384.9
# 565         29. West Bengal  2020-21  16524.4  594.7         2443.6   441.9
# 566         29. West Bengal  2021-22  16762.7  661.5           2651   427.1
#
# ...

# %%
numCols=['Rice', 'Wheat', 'Coarse cereals',
       'Pulses', 'Food- grains', 'Oilseeds', 'Cotton (Lint)', 'Sugar- cane',
       'Raw Jute & Mesta']

dataStates[numCols]=dataStates[numCols].replace(to_replace="-",value=0)
# Out:
# c:\users\chand\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
for col in numCols:
    
    print(col)
    
    dataStates[col]=dataStates[col].astype(float)
# Out:
# Rice
# Wheat
# Coarse cereals
# Pulses
# Food- grains
# Oilseeds
# Cotton (Lint)
# Sugar- cane
# Raw Jute & Mesta
# C:\Users\Chand\AppData\Local\Temp/ipykernel_16440/775800324.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataStates[col]=dataStates[col].astype(float)

# %%
dataAP=dataStates.loc[dataStates["State"]=="Andhra Pradesh"]

# %%
xAxis=dataAP["Year"]
yAxis=dataAP["Rice"]

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(111)
ax.plot(xAxis, yAxis)
plt.xticks(rotation=270)
plt.title("Rice Production In Andhra Pradesh 2002-2022")
# Out:
# Text(0.5, 1.0, 'Rice Production In Andhra Pradesh 2002-2022')

# %%
# Multiple Lines Rice vs Sugarcane in Andhra Pradesh

y2Axis=dataAP["Sugar- cane"]

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(111)
ax.plot(xAxis, yAxis,marker="8",markersize=10,color="green")
ax.plot(xAxis,y2Axis,marker="*",markersize=10,color="brown")
plt.xticks(rotation=270)
plt.title("Rice Vs Sugar-Cane Production In Andhra Pradesh 2002-2022")
plt.legend(["Rice","Sugar-Cane"])

# %% [markdown]
# Markers Documentation
# https://matplotlib.org/stable/api/markers_api.html

# %%
states=list(set(dataStates.State))

# %%
states
# Out:
# ['Meghalaya',
#  'Odisha',
#  'Jammu & Kashmir',
#  'Gujarat',
#  'Haryana',
#  'Nagaland',
#  'Mizoram',
#  'Sikkim',
#  'Maharashtra',
#  'Kerala',
#  'Punjab',
#  'Telangana',
#  'Andhra Pradesh',
#  'Karnataka',
#  'Uttar Pradesh',
#  'Chhattisgarh',
#  'Tripura',
#  'West Bengal',
#  'Madhya Pradesh',
#  'Goa',
#  'Rajasthan',
#  'Bihar',
#  'Assam',
#  'Tamil Nadu',
#  'Uttarakhand',
#  'Arunachal Pradesh',
#  'Jharkhand',
#  'Manipur',
#  'Himachal Pradesh']

# %%
# Rice Production Trend Across All STates

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(111)


for state in states:
    
    xAxis=dataStates.loc[dataStates["State"]==state,"Year"]
    
    yAxis=dataStates.loc[dataStates["State"]==state,"Rice"]
    
    ax.plot(xAxis, yAxis,marker="8",markersize=5)

plt.xticks(rotation=270)
plt.title("Rice Vs Sugar-Cane Production All States 2002-2022")
#plt.legend(states)
# Out:
# Text(0.5, 1.0, 'Rice Vs Sugar-Cane Production All States 2002-2022')

# %% [markdown]
# Bar Chart

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.bar(xAxis,yAxis,color="#800835",edgecolor="black",label="Rice",)
ax.bar(xAxis,y2Axis,bottom=yAxis,edgecolor="black",label="wheat")

ax.legend(loc="upper left")

plt.xticks(rotation=270)
plt.title("Rice Production In Andhra Pradesh (2002-2022)")

plt.show()

# %%
# Horizontal Bars

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.barh(xAxis,yAxis,color="brown",edgecolor="black")
plt.xticks(rotation=270)
plt.title("Rice Production In Andhra Pradesh (2002-2022)")

plt.show()

# %%
# Seaborn # Plotly
