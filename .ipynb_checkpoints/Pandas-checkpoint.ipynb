# %% [markdown]
# 1) Creating DataFrame
#     * read_csv
#     * read_json
#     * from_dict
#     * read_excel
#     * read_tsv
# 2) DataTypes Configure
# 3) Indexing
# 4) Joining
# 5) Pivoting
# 6) Mathematical Operations
# 7) Data Analytics Functions

# %% [markdown]
# Creation of a dataframe

# %%
import pandas as pd

# %%
data=pd.read_csv("DaywiseReport.csv")

# %%
data.head(10)
# Out:
#      client businessmodel        stationcode   zone depositdate  \
# 0  RELIANCE   STATIONLESS               3204   WEST         NaN
# 1  RELIANCE   STATIONLESS               3204   WEST  2022-11-02
# 2   GROFERS   STATIONLESS               AHM1  NORTH  2022-11-11
# 3    AMAZON   STATIONLESS               AIID  NORTH         NaN
# 4    AMAZON   STATIONLESS               AIID  NORTH  2022-11-02
# 5  FLIPKART   STATIONLESS  AhmedNagarHub_AHN   WEST  2022-11-15
# 6  FLIPKART   STATIONLESS       BopalHub_AMD   WEST         NaN
# 7      CIPL       STATION  CIPL-West Tripura   EAST         NaN
# 8      CIPL       STATION         CIPL-Wokha   EAST  2022-11-03
# 9      CIPL       STATION      CIPL_SIBSAGAR   EAST  2022-11-10
#
#   remittancedate depositref remittanceref  amountcollected  amountdeposited  \
# 0     2022-11-02        NaN       SL00017           5000.0              0.0
# 1            NaN      SA120           NaN              0.0           5000.0
# 2     2022-11-11    SL00002       SL00002          20000.0          20000.0
# 3     2022-11-02        NaN       SL00015           5200.0              0.0
# 4            NaN   SA123456           NaN              0.0           5200.0
# 5     2022-11-15    SL00006       SL00006           5000.0           5000.0
# 6     2022-11-25        NaN       SL00013          36000.0              0.0
# 7     2022-11-10        NaN       SL00003           5000.0              0.0
# 8     2022-11-03    SL00008       SL00008           1000.0           1000.0
# 9     2022-11-10    SL00005       SL00005          12000.0          12000.0
#
#    amountpending
# 0         5000.0
# 1        -5000.0
# 2            0.0
# 3         5200.0
# 4        -5200.0
# 5            0.0
# 6        36000.0
# 7         5000.0
# 8            0.0
# 9            0.0

# %%
data.tail(5)
# Out:
#             client          businessmodel                stationcode   zone  \
# 13        FLIPKART            STATIONLESS               DewasHub_DWS   WEST
# 14        FLIPKART            STATIONLESS  ElasticRunPanihatiODH_KOL   EAST
# 15          AMAZON                STATION                       GSPD  NORTH
# 16  Kirana Konnect  OFFICE KIRANA CONNECT         Kirana_Konnect_IDR   WEST
# 17        FLIPKART            STATIONLESS        OrderlyBazarHub_VNS  NORTH
#
#    depositdate remittancedate depositref remittanceref  amountcollected  \
# 13  2022-11-05     2022-11-05    SL00012       SL00012         123456.0
# 14         NaN     2022-11-10        NaN       SL00007          50000.0
# 15  2022-11-17     2022-11-17    SL00011       SL00011          10000.0
# 16  2022-11-09     2022-11-09    SL00009       SL00009           5000.0
# 17         NaN     2022-11-30        NaN       SL00016            120.0
#
#     amountdeposited  amountpending
# 13         123456.0            0.0
# 14              0.0        50000.0
# 15          10000.0            0.0
# 16           2500.0         2500.0
# 17              0.0          120.0

# %%
cols=list(data.columns)

# %%
cols
# Out:
# ['client',
#  'businessmodel',
#  'stationcode',
#  'zone',
#  'depositdate',
#  'remittancedate',
#  'depositref',
#  'remittanceref',
#  'amountcollected',
#  'amountdeposited',
#  'amountpending']

# %% [markdown]
# Read Json

# %%
import json

# %%
jsFile=open("Sample.json","w")

# %%
obj=[{"Transaction ID":"TR1","Item":"Idly","Qty":5,"Rate":10,"Amount":50},
     {"Transaction ID":"TR2","Item":"Dosa","Qty":3,"Rate":50,"Amount":150}]

# %%
jsFile.write(json.dumps(obj))
# Out:
# 159

# %%
jsFile.close()

# %%
txnsHotel=pd.read_json("Sample.json",orient="records")

# %%
txnsHotel
# Out:
#   Transaction ID  Item  Qty  Rate  Amount
# 0            TR1  Idly    5    10      50
# 1            TR2  Dosa    3    50     150

# %% [markdown]
# 3) From Dictionary

# %%
txnHotelObj={"Transaction ID":["TR1","TR2"],"Item":["Idly","Dosa"],"Qty":[5,3],"Rate":[10,50],"Amount":[50,150]}

# %%
txnHotel2=pd.DataFrame(txnHotelObj)

# %%
txnHotel2
# Out:
#   Transaction ID  Item  Qty  Rate  Amount
# 0            TR1  Idly    5    10      50
# 1            TR2  Dosa    3    50     150

# %%
txnHotel3=pd.DataFrame.from_dict(obj,orient="columns")

# %%
txnHotel3
# Out:
#   Transaction ID  Item  Qty  Rate  Amount
# 0            TR1  Idly    5    10      50
# 1            TR2  Dosa    3    50     150

# %%
obj
# Out:
# [{'Transaction ID': 'TR1', 'Item': 'Idly', 'Qty': 5, 'Rate': 10, 'Amount': 50},
#  {'Transaction ID': 'TR2',
#   'Item': 'Dosa',
#   'Qty': 3,
#   'Rate': 50,
#   'Amount': 150}]

# %% [markdown]
# Read Excel

# %%
dataTxn=pd.read_excel("TxnsHotel.xlsx",sheet_name=None)

# %%
dataTxn["Txns"]
# Out:
#   Transaction ID  Item  Qty  Rate  Amount
# 0            TR1  Idly   10    10     100
# 1            TR2  Idly   11    10     110
# 2            TR3  Idly   12    10     120
# 3            TR4  Idly   13    10     130
# 4            TR5  Idly   14    10     140
# 5            TR6  Dosa    3    50     150
# 6            TR7  Dosa    4    50     200
# 7            TR8  Dosa    5    50     250
# 8            TR9  Dosa    6    50     300

# %%
dataTxn["DiscPerc"]
# Out:
#      Item  Disc Perc
# 0    Idly          5
# 1    Dosa          3
# 2  Pongal          3

# %% [markdown]
# Tab Seperated Value

# %%
dataTSV=pd.read_csv("TxnsHotelTABsep.txt",delimiter="\t")

# %%
dataTSV
# Out:
#   Transaction ID  Item  Qty  Rate  Amount
# 0            TR1  Idly   10    10     100
# 1            TR2  Idly   11    10     110
# 2            TR3  Idly   12    10     120
# 3            TR4  Idly   13    10     130
# 4            TR5  Idly   14    10     140
# 5            TR6  Dosa    3    50     150
# 6            TR7  Dosa    4    50     200
# 7            TR8  Dosa    5    50     250
# 8            TR9  Dosa    6    50     300

# %%
data.to_json("CSVtoJsonSample.json",orient="records")

# %%
data.to_csv("DF2CSV.csv")

# %%
data.to_csv("DF2TSV.tsv",sep="\t")

# %%
data.to_excel("DF2Excel.xlsx",sheet_name="Sample")

# %%
data.dtypes
# Out:
# client              object
# businessmodel       object
# stationcode         object
# zone                object
# depositdate         object
# remittancedate      object
# depositref          object
# remittanceref       object
# amountcollected    float64
# amountdeposited    float64
# amountpending      float64
# dtype: object

# %%
data["depositdate"]
# Out:
# 0            NaN
# 1     2022-11-02
# 2     2022-11-11
# 3            NaN
# 4     2022-11-02
# 5     2022-11-15
# 6            NaN
# 7            NaN
# 8     2022-11-03
# 9     2022-11-10
# 10    2022-12-03
# 11    2022-11-11
# 12           NaN
# 13    2022-11-05
# 14           NaN
# 15    2022-11-17
# 16    2022-11-09
# 17           NaN
# Name: depositdate, dtype: object

# %%
data["depositdate"]=pd.to_datetime(data["depositdate"])

# %%
data.dtypes
# Out:
# client                     object
# businessmodel              object
# stationcode                object
# zone                       object
# depositdate        datetime64[ns]
# remittancedate             object
# depositref                 object
# remittanceref              object
# amountcollected           float64
# amountdeposited           float64
# amountpending             float64
# dtype: object

# %%
data["amountcollected"]=data["amountcollected"].astype(float)

# %%
data.dtypes
# Out:
# client                     object
# businessmodel              object
# stationcode                object
# zone                       object
# depositdate        datetime64[ns]
# remittancedate             object
# depositref                 object
# remittanceref              object
# amountcollected           float64
# amountdeposited           float64
# amountpending             float64
# dtype: object

# %%
data["amountcollected"]=data["amountcollected"].astype(str)

# %%
[2,3,6,8,9]
# Out:
# [2, 3, 6, 8, 9]

# %%
max([2,3,6,8,9])
# Out:
# 9

# %%
max(data["amountcollected"])
# Out:
# 123456.0

# %%
data["amountcollected"].sum()
# Out:
# 292426.0

# %%
data
# Out:
#             client          businessmodel                     stationcode  \
# 0         RELIANCE            STATIONLESS                            3204
# 1         RELIANCE            STATIONLESS                            3204
# 2          GROFERS            STATIONLESS                            AHM1
# 3           AMAZON            STATIONLESS                            AIID
# 4           AMAZON            STATIONLESS                            AIID
# 5         FLIPKART            STATIONLESS               AhmedNagarHub_AHN
# 6         FLIPKART            STATIONLESS                    BopalHub_AMD
# 7             CIPL                STATION               CIPL-West Tripura
# 8             CIPL                STATION                      CIPL-Wokha
# 9             CIPL                STATION                   CIPL_SIBSAGAR
# 10        FLIPKART            STATIONLESS                   CacharHub_IXS
# 11        SNAPDEAL                STATION  DELSIVCIEDED : SIVSAGAR-NOWJAN
# 12          AMAZON            STATIONLESS                            DLIH
# 13        FLIPKART            STATIONLESS                    DewasHub_DWS
# 14        FLIPKART            STATIONLESS       ElasticRunPanihatiODH_KOL
# 15          AMAZON                STATION                            GSPD
# 16  Kirana Konnect  OFFICE KIRANA CONNECT              Kirana_Konnect_IDR
# 17        FLIPKART            STATIONLESS             OrderlyBazarHub_VNS
#
#      zone depositdate remittancedate depositref remittanceref  \
# 0    WEST         NaT     2022-11-02        NaN       SL00017
# 1    WEST  2022-11-02            NaN      SA120           NaN
# 2   NORTH  2022-11-11     2022-11-11    SL00002       SL00002
# 3   NORTH         NaT     2022-11-02        NaN       SL00015
# 4   NORTH  2022-11-02            NaN   SA123456           NaN
# 5    WEST  2022-11-15     2022-11-15    SL00006       SL00006
# 6    WEST         NaT     2022-11-25        NaN       SL00013
# 7    EAST         NaT     2022-11-10        NaN       SL00003
# 8    EAST  2022-11-03     2022-11-03    SL00008       SL00008
# 9    EAST  2022-11-10     2022-11-10    SL00005       SL00005
# 10   EAST  2022-12-03     2022-11-03    SL00010       SL00010
# 11   EAST  2022-11-11     2022-11-11    SL00004       SL00004
# 12  NORTH         NaT     2022-11-29        NaN       SL00014
# 13   WEST  2022-11-05     2022-11-05    SL00012       SL00012
# 14   EAST         NaT     2022-11-10        NaN       SL00007
# 15  NORTH  2022-11-17     2022-11-17    SL00011       SL00011
# 16   WEST  2022-11-09     2022-11-09    SL00009       SL00009
# 17  NORTH         NaT     2022-11-30        NaN       SL00016
#
#     amountcollected  amountdeposited  amountpending
# 0            5000.0              0.0         5000.0
# 1               0.0           5000.0        -5000.0
# 2           20000.0          20000.0            0.0
# 3            5200.0              0.0         5200.0
# 4               0.0           5200.0        -5200.0
# 5            5000.0           5000.0            0.0
# 6           36000.0              0.0        36000.0
# 7            5000.0              0.0         5000.0
# 8            1000.0           1000.0            0.0
# 9           12000.0          12000.0            0.0
# 10           8000.0           8000.0            0.0
# 11           6500.0           6500.0            0.0
# 12            150.0              0.0          150.0
# 13         123456.0         123456.0            0.0
# 14          50000.0              0.0        50000.0
# 15          10000.0          10000.0            0.0
# 16           5000.0           2500.0         2500.0
# 17            120.0              0.0          120.0

# %%
data["balance"]=data["amountcollected"]-data["amountdeposited"]

# %%
data
# Out:
#             client          businessmodel                     stationcode  \
# 0         RELIANCE            STATIONLESS                            3204
# 1         RELIANCE            STATIONLESS                            3204
# 2          GROFERS            STATIONLESS                            AHM1
# 3           AMAZON            STATIONLESS                            AIID
# 4           AMAZON            STATIONLESS                            AIID
# 5         FLIPKART            STATIONLESS               AhmedNagarHub_AHN
# 6         FLIPKART            STATIONLESS                    BopalHub_AMD
# 7             CIPL                STATION               CIPL-West Tripura
# 8             CIPL                STATION                      CIPL-Wokha
# 9             CIPL                STATION                   CIPL_SIBSAGAR
# 10        FLIPKART            STATIONLESS                   CacharHub_IXS
# 11        SNAPDEAL                STATION  DELSIVCIEDED : SIVSAGAR-NOWJAN
# 12          AMAZON            STATIONLESS                            DLIH
# 13        FLIPKART            STATIONLESS                    DewasHub_DWS
# 14        FLIPKART            STATIONLESS       ElasticRunPanihatiODH_KOL
# 15          AMAZON                STATION                            GSPD
# 16  Kirana Konnect  OFFICE KIRANA CONNECT              Kirana_Konnect_IDR
# 17        FLIPKART            STATIONLESS             OrderlyBazarHub_VNS
#
#      zone depositdate remittancedate depositref remittanceref  \
# 0    WEST         NaT     2022-11-02        NaN       SL00017
# 1    WEST  2022-11-02            NaN      SA120           NaN
# 2   NORTH  2022-11-11     2022-11-11    SL00002       SL00002
# 3   NORTH         NaT     2022-11-02        NaN       SL00015
# 4   NORTH  2022-11-02            NaN   SA123456           NaN
# 5    WEST  2022-11-15     2022-11-15    SL00006       SL00006
# 6    WEST         NaT     2022-11-25        NaN       SL00013
# 7    EAST         NaT     2022-11-10        NaN       SL00003
# 8    EAST  2022-11-03     2022-11-03    SL00008       SL00008
# 9    EAST  2022-11-10     2022-11-10    SL00005       SL00005
# 10   EAST  2022-12-03     2022-11-03    SL00010       SL00010
# 11   EAST  2022-11-11     2022-11-11    SL00004       SL00004
# 12  NORTH         NaT     2022-11-29        NaN       SL00014
# 13   WEST  2022-11-05     2022-11-05    SL00012       SL00012
# 14   EAST         NaT     2022-11-10        NaN       SL00007
# 15  NORTH  2022-11-17     2022-11-17    SL00011       SL00011
# 16   WEST  2022-11-09     2022-11-09    SL00009       SL00009
# 17  NORTH         NaT     2022-11-30        NaN       SL00016
#
#     amountcollected  amountdeposited  amountpending  balance
# 0            5000.0              0.0         5000.0   5000.0
# 1               0.0           5000.0        -5000.0  -5000.0
# 2           20000.0          20000.0            0.0      0.0
# 3            5200.0              0.0         5200.0   5200.0
# 4               0.0           5200.0        -5200.0  -5200.0
# 5            5000.0           5000.0            0.0      0.0
# 6           36000.0              0.0        36000.0  36000.0
# 7            5000.0              0.0         5000.0   5000.0
# 8            1000.0           1000.0            0.0      0.0
# 9           12000.0          12000.0            0.0      0.0
# 10           8000.0           8000.0            0.0      0.0
# 11           6500.0           6500.0            0.0      0.0
# 12            150.0              0.0          150.0    150.0
# 13         123456.0         123456.0            0.0      0.0
# 14          50000.0              0.0        50000.0  50000.0
# 15          10000.0          10000.0            0.0      0.0
# 16           5000.0           2500.0         2500.0   2500.0
# 17            120.0              0.0          120.0    120.0

# %%
data["client"]+data["amountcollected"]
# Out:
# 0           RELIANCE5000.0
# 1              RELIANCE0.0
# 2           GROFERS20000.0
# 3             AMAZON5200.0
# 4                AMAZON0.0
# 5           FLIPKART5000.0
# 6          FLIPKART36000.0
# 7               CIPL5000.0
# 8               CIPL1000.0
# 9              CIPL12000.0
# 10          FLIPKART8000.0
# 11          SNAPDEAL6500.0
# 12             AMAZON150.0
# 13        FLIPKART123456.0
# 14         FLIPKART50000.0
# 15           AMAZON10000.0
# 16    Kirana Konnect5000.0
# 17           FLIPKART120.0
# dtype: object

# %% [markdown]
# 3) Indexing

# %%
txnDF=dataTxn["Txns"]

# %%
txnDF["Qty"][4]
# Out:
# 14

# %%
txnDF.loc[4]
# Out:
# Transaction ID     TR5
# Item              Idly
# Qty                 14
# Rate                10
# Amount             140
# Name: 4, dtype: object

# %%
txnDF.Rate[4]
# Out:
# 10

# %%
txnDF
# Out:
#   Transaction ID  Item  Qty  Rate  Amount
# 0            TR1  Idly   10    10     100
# 1            TR2  Idly   11    10     110
# 2            TR3  Idly   12    10     120
# 3            TR4  Idly   13    10     130
# 4            TR5  Idly   14    10     140
# 5            TR6  Dosa    3    50     150
# 6            TR7  Dosa    4    50     200
# 7            TR8  Dosa    5    50     250
# 8            TR9  Dosa    6    50     300

# %%
txnDF.index[txnDF["Transaction ID"]=="TR4"]
# Out:
# Int64Index([3], dtype='int64')

# %%
txnDF['Amount'][(txnDF["Transaction ID"]=="TR4")|(txnDF["Item"]=="Idly")]
# Out:
# 0    100
# 1    110
# 2    120
# 3    130
# 4    140
# Name: Amount, dtype: int64

# %%
txnDF["Amount"][~txnDF["Transaction ID"].isin(["TR4","TR5","TR7"])]
# Out:
# 0    100
# 1    110
# 2    120
# 5    150
# 7    250
# 8    300
# Name: Amount, dtype: int64

# %%
~txnDF["Transaction ID"].isin(["TR4","TR5","TR7"])
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# 8     True
# Name: Transaction ID, dtype: bool

# %%
txnDF["Transaction ID"][txnDF["Amount"]>150]
# Out:
# 6    TR7
# 7    TR8
# 8    TR9
# Name: Transaction ID, dtype: object

# %% [markdown]
# Joining
#
# * Inner Join
# * Left Join
# * Right Join
# * Outer Join

# %%
dataTxn
# Out:
# {'Txns':   Transaction ID  Item  Qty  Rate  Amount
#  0            TR1  Idly   10    10     100
#  1            TR2  Idly   11    10     110
#  2            TR3  Idly   12    10     120
#  3            TR4  Idly   13    10     130
#  4            TR5  Idly   14    10     140
#  5            TR6  Dosa    3    50     150
#  6            TR7  Dosa    4    50     200
#  7            TR8  Dosa    5    50     250
#  8            TR9  Dosa    6    50     300,
#  'DiscPerc':      Item  Disc Perc
#  0    Idly          5
#  1    Dosa          3
#  2  Pongal          3}

# %%
txnDF=txnDF.append(pd.DataFrame({"Transaction ID":["TR10"],"Item":["Poori"],"Qty":[3],"Rate":[25],"Amount":[75]}))

# %%
pd.merge(left=txnDF,right=dataTxn["DiscPerc"],how="right",left_on="Item",right_on="Item")
# Out:
#   Transaction ID    Item   Qty  Rate  Amount  Disc Perc
# 0            TR1    Idly  10.0  10.0   100.0          5
# 1            TR2    Idly  11.0  10.0   110.0          5
# 2            TR3    Idly  12.0  10.0   120.0          5
# 3            TR4    Idly  13.0  10.0   130.0          5
# 4            TR5    Idly  14.0  10.0   140.0          5
# 5            TR6    Dosa   3.0  50.0   150.0          3
# 6            TR7    Dosa   4.0  50.0   200.0          3
# 7            TR8    Dosa   5.0  50.0   250.0          3
# 8            TR9    Dosa   6.0  50.0   300.0          3
# 9            NaN  Pongal   NaN   NaN     NaN          3

# %%
pd.merge(left=txnDF,right=dataTxn["DiscPerc"],how="left",left_on="Item",right_on="Item")
# Out:
#   Transaction ID   Item  Qty  Rate  Amount  Disc Perc
# 0            TR1   Idly   10    10     100        5.0
# 1            TR2   Idly   11    10     110        5.0
# 2            TR3   Idly   12    10     120        5.0
# 3            TR4   Idly   13    10     130        5.0
# 4            TR5   Idly   14    10     140        5.0
# 5            TR6   Dosa    3    50     150        3.0
# 6            TR7   Dosa    4    50     200        3.0
# 7            TR8   Dosa    5    50     250        3.0
# 8            TR9   Dosa    6    50     300        3.0
# 9           TR10  Poori    3    25      75        NaN

# %%
pd.merge(left=txnDF,right=dataTxn["DiscPerc"],how="inner",left_on="Item",right_on="Item")
# Out:
#   Transaction ID  Item  Qty  Rate  Amount  Disc Perc
# 0            TR1  Idly   10    10     100          5
# 1            TR2  Idly   11    10     110          5
# 2            TR3  Idly   12    10     120          5
# 3            TR4  Idly   13    10     130          5
# 4            TR5  Idly   14    10     140          5
# 5            TR6  Dosa    3    50     150          3
# 6            TR7  Dosa    4    50     200          3
# 7            TR8  Dosa    5    50     250          3
# 8            TR9  Dosa    6    50     300          3

# %%
pd.merge(left=txnDF,right=dataTxn["DiscPerc"],how="outer",left_on="Item",right_on="Item")
# Out:
#    Transaction ID    Item   Qty  Rate  Amount  Disc Perc
# 0             TR1    Idly  10.0  10.0   100.0        5.0
# 1             TR2    Idly  11.0  10.0   110.0        5.0
# 2             TR3    Idly  12.0  10.0   120.0        5.0
# 3             TR4    Idly  13.0  10.0   130.0        5.0
# 4             TR5    Idly  14.0  10.0   140.0        5.0
# 5             TR6    Dosa   3.0  50.0   150.0        3.0
# 6             TR7    Dosa   4.0  50.0   200.0        3.0
# 7             TR8    Dosa   5.0  50.0   250.0        3.0
# 8             TR9    Dosa   6.0  50.0   300.0        3.0
# 9            TR10   Poori   3.0  25.0    75.0        NaN
# 10            NaN  Pongal   NaN   NaN     NaN        3.0
